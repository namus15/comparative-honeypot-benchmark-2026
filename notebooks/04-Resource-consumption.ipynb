# %% [markdown]
# # 04 - Consumo de Recursos Computacionales
#
# Análisis de CPU, RAM y almacenamiento de logs de los 6 honeypots.
#
# Resultados clave (96 días):
# - Tradicionales: bajo consumo (9–18 % CPU)
# - ML-enhanced: mayor consumo (34–62 % CPU)
# - Baseline propio (Cowrie + IF): mejor balance
#
# Versión final - 2 de abril de 2026

# %%
print("Notebook 04 - Consumo de recursos")
print("Promedio ML-enhanced: 48 % CPU | Tradicional: 15 % CPU")
