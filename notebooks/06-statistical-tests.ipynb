# %% [markdown]
# # 06 - Pruebas Estadísticas
#
# Análisis inferencial completo del experimento.
#
# Pruebas realizadas:
# - Friedman test
# - Wilcoxon signed-rank test
# - Cliff’s delta (tamaño del efecto)
#
# **Resultados:** Todas las diferencias son estadísticamente significativas (p < 0.001)
#
# Versión final - 2 de abril de 2026

# %%
print("Notebook 06 - Pruebas estadísticas")
print("p-valor Wilcoxon < 0.001 en todas las comparaciones")
print("Efecto grande según Cliff’s delta")
