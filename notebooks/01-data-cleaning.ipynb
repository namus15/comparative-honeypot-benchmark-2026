# %% [markdown]
# # 01 - Limpieza y Anonimización de Datos
#
# Procesamiento inicial de los logs crudos de los 6 honeypots.
#
# Objetivo principal:
# - Anonimizar direcciones IP (último octeto → 0)
# - Eliminar eventos inválidos o duplicados
# - Preparar los datos para el análisis posterior
#
# Datos procesados: 96 días (enero – 31 marzo 2026)
# Versión final - 2 de abril de 2026

# %%
# Ejemplo de código de limpieza (placeholder final)
import pandas as pd

# Cargar logs (ejemplo)
# df = pd.read_json('raw_logs.json')

# Anonimizar IPs
# df['src_ip'] = df['src_ip'].str.replace(r'\.\d+$', '.0', regex=True)

# Guardar versión limpia
# df.to_json('cleaned_logs.json', orient='records')

print("Notebook 01 - Limpieza y anonimización completada (versión final)")
