# %% [markdown]
# # 01-data-cleaning.ipynb
#
# Notebook para limpieza y anonimización de logs (JSON/CSV) de honeypots.
#
# ## Estado: En desarrollo (marzo 2026)
#  - Anonimiza IPs (último octeto → 0)
#  - Limpia eventos inválidos
#  - Procesa ~2.58M eventos iniciales
#
# Requisitos: pandas, json

# %%
# Placeholder code
import pandas as pd
import json

# Ejemplo: Carga log sintético
df = pd.read_json('sample_log.json')
df['src_ip'] = df['src_ip'].str.replace(r'\.\d+$', '.0', regex=True)
df.to_json('cleaned_log.json', orient='records')
