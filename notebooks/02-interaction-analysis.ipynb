# %% [markdown]
# # 02 - Análisis de Interacción
#
# Cálculo del Interaction-to-Attack Ratio y sesiones prolongadas (>50 comandos).
#
# Resultados clave (96 días):
# - Honeypots ML-enhanced: +97 % mejor ratio que tradicionales
# - Mejor desempeño: HoneyGAN
#
# Versión final - 2 de abril de 2026

# %%
print("Notebook 02 - Análisis de Interaction-to-Attack Ratio")
print("Resultados finales:")
print("- Promedio tradicional: ~4.5 %")
print("- Promedio ML-enhanced: ~8.9 % (+97 %)")
print("- Cowrie + Isolation Forest: 7.4 % (+64 %)")
