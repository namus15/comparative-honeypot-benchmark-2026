# %% [markdown]
# # 03 - Resistencia a Fingerprinting
#
# Análisis de detección por herramientas automatizadas (Nmap, p0f, ZGrab2, Honeyscore Shodan).
#
# Resultados clave (96 días):
# - Promedio tradicional: 91.4 % detección
# - ML-enhanced: reducción entre 41 % y 64 %
# - Mejor resultado: HoneyGAN (32.8 % detección)
#
# Versión final - 2 de abril de 2026

# %%
print("Notebook 03 - Análisis de resistencia a fingerprinting")
print("Honeyscore Shodan promedio ML-enhanced: 0.0 - 0.1")
