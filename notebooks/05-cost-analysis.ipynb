# %% [markdown]
# # 05 - Análisis de Costos Operacionales y ROI
#
# Cálculo de TCO (Total Cost of Ownership) y período de amortización.
#
# Resultados clave (96 días):
# - ROI promedio ML-enhanced: 8–11 meses
# - Mejor ROI: Cowrie + Isolation Forest (8 meses)
# - Ahorro anual neto después de ROI: +8.148 USD
#
# Versión final - 2 de abril de 2026

# %%
print("Notebook 05 - Análisis de costos y ROI")
print("ROI promedio: 10.8 meses")
